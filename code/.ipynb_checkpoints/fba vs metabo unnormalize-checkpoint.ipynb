# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
t = pd.read_excel('../result/metabo_mean.xlsx')
fba = pd.read_csv('../result/fba_abs.csv', index_col=0)
a = fba.loc[[
    'R00268', 'R01056', 'R01049', 'R04779', 
    'R00342', 'R01082', 'R01325', 'R02740'
]].sort_index()
a.index = [
    'akg', 'R5P→R5P', 'PRPP', 'F6P→F1,6P', 'Oxaloacetate, Malate', 
    'Malate, Fumarate', 'Citrate', 'G6P→F6P'
]

# %%
t.loc[['Glucose 1-phosphate']]
# Out:
#                       Control   Clone A   Clone B
# Glucose 1-phosphate  1.103544  6.888668  1.545911

# %%
b = []
for i in t.columns:
    b.append(sum(t.loc[['Cytosine', 'Uracil', 'Adenine', 'Guanine']][i]))

# %%
pd.Series(np.array(b)/b[0]).plot()
pd.Series(np.array(a.T['PRPP'])/a.T['PRPP'][0], index =['Con', 'Clone A', 'Clone B']).plot(kind='bar')

# %%
b = t.loc['Ribulose 5-phosphate']

# %%
pd.Series(np.array(b)/b[0]).plot()
pd.Series(np.array(a.T['R5P→R5P'])/a.T['R5P→R5P'][0], index =['Con', 'Clone A', 'Clone B']).plot(kind='bar')

# %%
b = t.loc['AMP']

# %%
pd.Series(np.array(b)/b[0]).plot()
pd.Series(np.array(a.T['akg'])/a.T['akg'][0], index =['Con', 'Clone A', 'Clone B']).plot(kind='bar')

# %%
b = t.loc['Ribose 5-phosphate']

# %%
pd.Series(np.array(b)/b[0]).plot()
pd.Series(np.array(a.T['R5P→R5P'])/a.T['R5P→R5P'][0], index =['Con', 'Clone A', 'Clone B']).plot(kind='bar')

# %%
b = t.loc['Fructose 1,6-diphosphate']

# %%
pd.Series(np.array(b)/b[0]).plot()
pd.Series(np.array(a.T['F6P→F1,6P'])/a.T['F6P→F1,6P'][0], index =['Con', 'Clone A', 'Clone B']).plot(kind='bar')

# %%
b = t.loc['Malic acid']

# %%
pd.Series(np.array(b)/b[0]).plot()
pd.Series(np.array(a.T['Malate, Fumarate'])/a.T['Malate, Fumarate'][0], index =['Con', 'Clone A', 'Clone B']).plot(kind='bar')

# %%
b = t.loc['Malic acid']

# %%
pd.Series(np.array(b)/b[0]).plot()
pd.Series(np.array(a.T['Oxaloacetate, Malate'])/a.T['Oxaloacetate, Malate'][0], index =['Con', 'Clone A', 'Clone B']).plot(kind='bar')

# %%
b = t.loc['Citric acid']

# %%
pd.Series(np.array(b)/b[0]).plot()
pd.Series(np.array(a.T['Citrate'])/a.T['Citrate'][0], index =['Con', 'Clone A', 'Clone B']).plot(kind='bar')

# %%
b = t.loc['Fructose 6-phosphate']

# %%
pd.Series(np.array(b)/b[0]).plot()
pd.Series(np.array(a.T['F6P→F1,6P'])/a.T['F6P→F1,6P'][0], index =['Con', 'Clone A', 'Clone B']).plot(kind='bar')

# %%
b = t.loc['Glucose 6-phosphate']

# %%
pd.Series(np.array(b)/b[0]).plot()
pd.Series(np.array(a.T['G6P→F6P'])/a.T['G6P→F6P'][0], index =['Con', 'Clone A', 'Clone B']).plot(kind='bar')
