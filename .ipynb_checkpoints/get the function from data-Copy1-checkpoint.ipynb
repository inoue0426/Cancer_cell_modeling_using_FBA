# %%
from scipy.optimize import curve_fit
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
t = pd.read_csv('./KO.csv', index_col=0)

# %%
t
# Out:
#                        Day 0       Day 1       Day 2       Day 3     Day 1.1  \
# pH                   7.54700    7.575000    7.558000    7.532000    7.542000
# Glucose(mmol/L)     16.76325   17.540354   16.874265   16.374697   17.318324
# Lactate(mmol/L)      0.00000    0.000000    0.000000    0.000000    0.000000
# Glutamine(mmol/L)    1.93000    1.980000    1.800000    1.690000    1.900000
# Glutamate(mmol/L)    0.32000    0.000000    0.260000    0.250000    0.220000
# Na(mmol/L)         149.00000  153.000000  157.000000  160.000000  153.000000
# K(mmol/L)            4.20000    4.300000    4.400000    4.500000    4.300000
# NH4(mmol/L)          0.41000    0.510000    0.620000    0.680000    0.540000
#
#                       Day 2.1     Day 3.1     Day 1.2     Day 2.2     Day 3.2
# pH                   7.512000    7.467000    7.552000    7.546000    7.532000
# Glucose(mmol/L)     16.485712   15.042519   17.040787   17.373832   16.652235
# Lactate(mmol/L)      0.000000    3.441385    0.000000    0.000000    0.000000
# Glutamine(mmol/L)    1.570000    1.370000    1.920000    1.730000    1.590000
# Glutamate(mmol/L)    0.460000    0.530000    0.000000    0.310000    0.250000
# Na(mmol/L)         157.000000  160.000000  153.000000  156.000000  158.000000
# K(mmol/L)            4.400000    4.500000    4.300000    4.400000    4.400000
# NH4(mmol/L)          0.730000    0.900000    0.510000    0.640000    0.720000

# %%
def nonlinear_fit(x,a,b):
    return  b - a*np.exp(np.log(2)/20.3*24*x)

# %%
f = [
    'Glucose(mmol/L)', 
#     'Lactate(mmol/L)', 
    'Glutamate(mmol/L)', 'NH4(mmol/L)'
]

# %%
slope = []

# %% [markdown]
# ### Control

# %%
vvv = []
for i in f:
    y=np.array(list(t[['Day 0', 'Day 1', 'Day 2', 'Day 3']].T[i]))
    y = [yy for yy in y if yy != 0]
    x=np.array([xx for xx in range(0, len(y))])
    param, cov = curve_fit(nonlinear_fit, x, y, p0=[1, 3])
    sns.pointplot(x=x, y=y, join=False)
    sns.pointplot(x=x, y=nonlinear_fit(x, param[0], param[1]), markers="")
    plt.show()
    print(nonlinear_fit(x, param[0], param[1]))
    print(i)
    print(param[0], param[1])
    vvv.append(param[0])
slope.append(vvv)
# Out:
# [17.16666168 17.07885935 16.87960694 16.4274376 ]
# Glucose(mmol/L)
# 0.06917222111982527 17.235833898096608
# [0.30299728 0.28449511 0.2425076 ]
# Glutamate(mmol/L)
# 0.014576333225459821 0.31757361583551846
# [0.46356455 0.49238918 0.55780178 0.7062445 ]
# NH4(mmol/L)
# -0.02270855589275801 0.44085598940066306

# %%
slope
# Out:
# [[0.06917222111982527, 0.014576333225459821, -0.02270855589275801]]

# %% [markdown]
# ### Clone A

# %%
def nonlinear_fit(x,a,b):
    return  b - a*np.exp(np.log(2)/13*24*x)

# %%
vvv = []
for i in f:
    y=np.array(list(t[['Day 0', 'Day 1', 'Day 2', 'Day 3']].T[i]))
    y = [yy for yy in y if yy != 0]
    x=np.array([xx for xx in range(0, len(y))])
    param, cov = curve_fit(nonlinear_fit, x, y, p0=[1, 3])
    sns.pointplot(x=x, y=y, join=False)
    sns.pointplot(x=x, y=nonlinear_fit(x, param[0], param[1]), markers="")
    plt.show()
    print(nonlinear_fit(x, param[0], param[1]))
    print(i)
    print(param[0], param[1])
    vvv.append(param[0])
slope.append(vvv)
# Out:
# [17.13665606 17.09365623 16.93905446 16.38319867]
# Glucose(mmol/L)
# 0.016567684384970804 17.153223744925164
# [0.29889374 0.2869766  0.24412966]
# Glutamate(mmol/L)
# 0.004591633499600551 0.30348537713354945
# [0.48276558 0.49526411 0.54020136 0.70176895]
# NH4(mmol/L)
# -0.004815639081896735 0.47794993769293714

# %% [markdown]
# ### Clone B

# %%
def nonlinear_fit(x,a,b):
    return  b - a*np.exp(np.log(2)/17*24*x)

# %%
vvv = []
for i in f:
    y=np.array(list(t[['Day 0', 'Day 1', 'Day 2', 'Day 3']].T[i]))
    y = [yy for yy in y if yy != 0]
    x=np.array([xx for xx in range(0, len(y))])
    param, cov = curve_fit(nonlinear_fit, x, y, p0=[1, 3])
    sns.pointplot(x=x, y=y, join=False)
    sns.pointplot(x=x, y=nonlinear_fit(x, param[0], param[1]), markers="")
    plt.show()
    print(nonlinear_fit(x, param[0], param[1]))
    print(i)
    print(param[0], param[1])
    vvv.append(param[0])
slope.append(vvv)
# Out:
# [17.1566317  17.08689472 16.90135084 16.40768831]
# Glucose(mmol/L)
# 0.041994438233322516 17.198626134259065
# [0.30146434 0.28550231 0.24303334]
# Glutamate(mmol/L)
# 0.009612068270935994 0.31107641262194485
# [0.47108844 0.49288341 0.55087164 0.70515652]
# NH4(mmol/L)
# -0.013124566899529235 0.4579638691027857

# %%
pd.DataFrame(slope, columns=['Glucose', 'Glutamate', 'NH4'], index=['Control', 'Clone A', 'Clone B']).to_csv('./result/slope.csv')
