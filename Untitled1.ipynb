# %%
from scipy.optimize import curve_fit
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
fba = pd.read_csv('./result/fba_mse.csv', index_col=0)

# %%
y = fba.loc['Lactate_output'] 
x = fba.loc['Oxygen_input']

# %%
sns.pointplot(x, y, join=False)

# %%
def linear_fit(x, a, b):
    return a*x + b

# %%
param, cov = curve_fit(linear_fit, x, y)

# %%
array_y_fit = param[0] * x + param[1]

sns.pointplot(x, y, join=False)
sns.pointplot(x, array_y_fit, markers="")

# %%
param[0], param[1]
# Out:
# (8.616984980341062, -0.062184908640392646)
